# %%
import cv2 as cv
import random
import numpy as np
import sklearn as sk
import math
from matplotlib import pyplot as plt

# %% [markdown]
# # Perpendicular Bisector Method

# %%
def exists(l, val):
    for i in l:
        if i == val:
            return True
    return False

# %% [markdown]
# # RANSAC

# %% [markdown]
# ## genPoints() func

# %%
def genPoints():
    # Get points
    a = []
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if(img[i][j] == 255):
                a.append([i,j])
    # take 3 random points
    points = []
    temp = []
    i = 0
    # get 3 indices of points
    while(i < 3):
        num = random.randint(0,len(a))
        if(not exists(temp, num)):
            temp.append(num)
            i += 1
    # convert indices to points
    for i in temp:
        points.append(a[i])
    return points

# %% [markdown]
# ## findCircle() func

# %%
def findCircle():
    global points
    
    #t Generate Lines
    p1 = points[0]
    p2 = points[1]
    p3 = points[2]

    #line 1
    m1 = (p1[0]-p2[0])/(p1[1]-p2[1])
    m2 = (p1[0]-p3[0])/(p1[1]-p3[1])

    b1 = p1[0]-(m1*p1[1])
    b2 = p1[0]-(m2*p1[1])

#     #draw line 1
#     for x in np.linspace(min(p1[1],p2[1]), max(p1[1],p2[1]), (max(p1[1],p2[1]) - min(p1[1],p2[1]))*100):
#         y = (int) (m1*x + b1)
#         img[y][(int)(x)] = 255
#     #draw line 2
#     for x in np.linspace(min(p1[1],p3[1]), max(p1[1],p3[1]), (max(p1[1],p3[1]) - min(p1[1],p3[1]))*100):
#         y = (int) (m2*x + b2)
#         img[y][(int)(x)] = 255
    
    #calculate mid points
    lenx1 = max(p1[1],p2[1]) - min(p1[1],p2[1])
    lenx2 = max(p1[1],p3[1]) - min(p1[1],p3[1])

    mid1 = [(lenx1/2 + min(p1[1],p2[1])), (m1*(lenx1/2 + min(p1[1],p2[1])) + b1)]
    mid2 = [(lenx2/2 + min(p1[1],p3[1])), (m2*(lenx2/2 + min(p1[1],p3[1])) + b2)]

    #calculate perpendicular slopes
    pm1 = -1/m1  #still need to account for dividing by 0 or vsmall num??
    pm2 = -1/m2

    #find the perpendicular bisectors
    bb1 = mid1[1] - (pm1*mid1[0])
    bb2 = mid2[1] - (pm2*mid2[0])

    #find center of circle/intersection of bisectors
    center = []
    for x in np.linspace(0,img.shape[1],img.shape[1]*1000):
        y1 = (int) (pm1*x + bb1)
        y2 = (int) (pm2*x + bb2)
        
#         #draw bisector lines
#         if(y1 < img.shape[0] and y1 > 0 and x < 1024):
#             img[y1,(int)(x)] = 255
#         if(y2 < img.shape[0] and y2 > 0 and x < 1024):
#             img[y2,(int) (x)] = 255
        if(y1 == y2):
            center = [y1,(int)(x)]
    #calculate radius
    a = center[0] - p1[0]
    b = center[1] - p1[1]
    rad = (int) (math.hypot(a,b))
    
    return center[0],center[1],rad

# %% [markdown]
# ## countInlier(lim) func

# %%
def countInlier(lim):
    global inlierPoints

    inlierPoints = []
    a=[]
    count = 0
    check = np.zeros([img.shape[0],img.shape[1]])
    check = cv.circle(check, (currCircle[1],currCircle[0]), currCircle[2], 255, 1)
    
    # Get points in img
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if(img[i][j] == 255):
                a.append([i,j])

    #get points in check
    cPoints = []
    for i in range(check.shape[0]):
        for j in range(check.shape[1]):
            if(check[i][j] == 255):
                cPoints.append([i,j])
    
    #for each position of each point of circle, find if close to real
    for cp in cPoints:
        for p in a:
            dx = cp[1] - p[1]
            dy = cp[0] - p[0]
            dist = math.hypot(dx,dy)
            if(dist < lim):
                inlierPoints.append(cp)
                count += 1
                break    
    return count

# %% [markdown]
# ## RANSAC() func

# %%
def RANSAC(iterations, lim):
    
    global currCircle
    global bCircle
    global points
    
    I = 0 #iteration number
    C = -1 #max count
    K = 0
    bCircle = (0,0,0) #best circle (best_x, best_y, best_r)
    currCircle = (0,0,0)

    while(I < iterations):
        print("Iteration: " + str(I+1))
        points = genPoints()
        currCircle = findCircle()
        K = countInlier(lim)
        if(K > C):
            bCircle = currCircle
            C = K
        print("Max Count: " + str(C))
        I += 1
    return bCircle

# %% [markdown]
# # Post Processing

# %%
def reCircle(inliers):
    
    global inlierRads
    inlierRads = []
    
    inlierPoints = []
    temp = []
    
    check = np.zeros([img.shape[0],img.shape[1]])
    check = cv.circle(check, (res[0],res[1]), res[2], 255, 1)
    
    # Get points in img
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if(img[i][j] == 255):
                temp.append([i,j])

    #get points in check
    cPoints = []
    for i in range(check.shape[0]):
        for j in range(check.shape[1]):
            if(check[i][j] == 255):
                cPoints.append([i,j])
    
    #for each position of each point of circle, find if close to real
    for cp in cPoints:
        for p in temp:
            dx = cp[1] - p[1]
            dy = cp[0] - p[0]
            dist = math.hypot(dx,dy)
            if(dist < 1):
                inlierPoints.append(cp)
                break   
                
    sum_x = 0
    sum_y = 0
    length = len(inlierPoints)
    for i in range(len(inlierPoints)):
        sum_x += inlierPoints[i][1]
        sum_y += inlierPoints[i][0]
    
    center = [(int)(sum_x/length), (int)(sum_y/length)]
    
    rad = 0
    for p in inliers:
        #calculate radius
        a = center[0] - p[0]
        b = center[1] - p[1]
        rad += (math.hypot(a,b))
    rad = (int)(rad/len(inliers))
    
    
    return center[0],center[1],rad

# %% [markdown]
# # Circle

# %%
img = cv.imread("circle.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY) #gray scale
img = cv.GaussianBlur(img, (5,5), cv.BORDER_DEFAULT) #smoothing
img = cv.Canny(img, 7, 51)

res = RANSAC(5,5)
postRes = reCircle(inlierPoints)
# Out:
# Iteration: 1
# Max Count: 159
# Iteration: 2
# Max Count: 2052
# Iteration: 3
# Max Count: 2052
# Iteration: 4
# Max Count: 2052
# Iteration: 5
# Max Count: 2056

# %% [markdown]
# ## Original

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## RANSAC Result

# %%
# Circle Center and Radius
print("Center = (" + str(res[1])+","+str(res[0])+")")
print("Radius = " + str(res[2]))
# Out:
# Center = (511,382)
# Radius = 364

# %%
check = img.copy()
check = cv.circle(check, (res[1],res[0]), res[2], 255, 1)
plt.imshow(check,cmap='gray')

# %% [markdown]
# ## Post Processing Result

# %%
# Circle Center and Radius
print("Center = (" + str(postRes[0])+","+str(postRes[1])+")")
print("Radius = " + str(postRes[2]))
# Out:
# Center = (421,417)
# Radius = 370

# %%
copy = img.copy()

copy = cv.circle(copy, (postRes[0],postRes[1]), postRes[2], 255, 1)

plt.imshow(copy,cmap='gray')

# %% [markdown]
# # Concentric Circles

# %%
img = cv.imread("concentric_circles.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY) #gray scale
img = cv.GaussianBlur(img, (5,5), cv.BORDER_DEFAULT) #smoothing
img = cv.Canny(img, 7, 51)

res = RANSAC(5,5)
postRes = reCircle(inlierPoints)
# Out:
# Iteration: 1
# Max Count: 210
# Iteration: 2
# Max Count: 551
# Iteration: 3
# Max Count: 551
# Iteration: 4
# Max Count: 551
# Iteration: 5
# Max Count: 551

# %% [markdown]
# ## Original Image

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## RANSAC Result

# %%
# Circle Center and Radius
print("Center = (" + str(res[1])+","+str(res[0])+")")
print("Radius = " + str(res[2]))
# Out:
# Center = (121,134)
# Radius = 114

# %%
check = img.copy()
check = cv.circle(check, (res[1],res[0]), res[2], 255, 1)
plt.imshow(check,cmap='gray')

# %% [markdown]
# ## Post Processing Result

# %%
# Circle Center and Radius
print("Center = (" + str(postRes[0])+","+str(postRes[1])+")")
print("Radius = " + str(postRes[2]))
# Out:
# Center = (145,147)
# Radius = 92

# %%
copy = img.copy()

copy = cv.circle(copy, (postRes[0],postRes[1]), postRes[2], 255, 1)

plt.imshow(copy,cmap='gray')

# %% [markdown]
# # Parliament Clock

# %%
img = cv.imread("parliament_clock.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY) #gray scale
img = cv.GaussianBlur(img, (5,5), cv.BORDER_DEFAULT) #smoothing
img = cv.Canny(img, 7, 51)

res = RANSAC(5,5)
postRes = reCircle(inlierPoints)
# Out:
# Iteration: 1
# Max Count: 206
# Iteration: 2
# Max Count: 206
# Iteration: 3
# Max Count: 302
# Iteration: 4
# Max Count: 303
# Iteration: 5
# Max Count: 353

# %% [markdown]
# ## Original Image

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## RANSAC Result

# %%
# Circle Center and Radius
print("Center = (" + str(res[1])+","+str(res[0])+")")
print("Radius = " + str(res[2]))
# Out:
# Center = (98,103)
# Radius = 78

# %%
check = img.copy()
check = cv.circle(check, (res[1],res[0]), res[2], 255, 1)
plt.imshow(check,cmap='gray')

# %% [markdown]
# ## Post Processing Result

# %%
# Circle Center and Radius
print("Center = (" + str(postRes[0])+","+str(postRes[1])+")")
print("Radius = " + str(postRes[2]))
# Out:
# Center = (91,81)
# Radius = 76

# %%
copy = img.copy()

copy = cv.circle(copy, (postRes[0],postRes[1]), postRes[2], 255, 1)

plt.imshow(copy,cmap='gray')
