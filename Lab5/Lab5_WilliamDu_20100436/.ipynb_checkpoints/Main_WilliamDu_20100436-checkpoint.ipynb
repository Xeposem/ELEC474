# %%
import cv2 as cv
import math
import numpy as np
from matplotlib import pyplot as plt
import random as rng

# %%
sift = cv.SIFT_create()
bf = cv.BFMatcher()

# %%
def calcFMatrix(img1, img2):
    kp1, des1 = sift.detectAndCompute(img1,None)
    kp2, des2 = sift.detectAndCompute(img2,None)
    matches = bf.knnMatch(des1,des2,k=2)
    inlier1 = []
    inlier2 = []
    for m,n in matches:
        if(m.distance < 0.75*n.distance):
            inlier2.append(kp2[m.trainIdx].pt)
            inlier1.append(kp1[m.queryIdx].pt)
    inlier1 = np.int32(inlier1)
    inlier2 = np.int32(inlier2)
    F, mask = cv.findFundamentalMat(inlier1,inlier2,cv.FM_LMEDS)
    inlier1 = inlier1[mask.ravel()==1]
    inlier2 = inlier2[mask.ravel()==1]
    return F, inlier1, inlier2

# %%
def imgRect(img1,img2,points1,points2,F,imgSize):
    res,H1,H2 = cv.stereoRectifyUncalibrated(points1,points2,F,imgSize)
    out1 = cv.warpPerspective(img1, H1, imgSize)
    out2 = cv.warpPerspective(img2, H2, imgSize)
    return out1,out2

# %%
def calcDispMap(img1,img2,numDisp,blockSize):
    stereo = cv.StereoBM_create(numDisp, blockSize)
    disp = stereo.compute(img1, img2)
    return disp

# %%
img1 = cv.imread("tape_r.jpg")
img2 = cv.imread("tape_l.jpg")
img1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
img2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

# %%
plt.imshow(img1,cmap='gray')

# %%
F,inlier1,inlier2 = calcFMatrix(img1,img2)

# %%
out1,out2 = imgRect(img1,img2,inlier1,inlier2,F,(img1.shape[1],img1.shape[0]))

# %%
plt.imshow(out2,cmap='gray')

# %%
plt.imshow(out1,cmap='gray')

# %%
disp = calcDispMap(img1,img2,16,15)

# %%
disp
# Out:
# array([[-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16],
#        ...,
#        [-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16]], dtype=int16)

# %%
plt.imshow(disp,cmap='gray')

# %%
stereo = cv.StereoBM_create(16, 15)
disp = stereo.compute(img1, img2, "32F")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-154-41d3495ac809> in <module>
#       1 stereo = cv.StereoBM_create(16, 15)
# ----> 2 disp = stereo.compute(img1, img2, "32F")
#
# error: OpenCV(4.5.4-dev) :-1: error: (-5:Bad argument) in function 'compute'
# > Overload resolution failed:
# >  - disparity is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'disparity'

# %%
disp
# Out:
# array([[-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16],
#        ...,
#        [-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16],
#        [-16, -16, -16, ..., -16, -16, -16]], dtype=int16)
